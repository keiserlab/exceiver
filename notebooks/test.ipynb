# %%
import numpy as np
import scanpy as sc

# %%
train = sc.read_h5ad("/scratch/ukhan/tabula-sapiens/baseline-otf/train.h5ad")

# %%
train
# Out:
# AnnData object with n_obs × n_vars = 336784 × 19067
#     obs: 'organ_tissue', 'method', 'donor', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'gender', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'gene_symbol', 'feature_type', 'ensemblid', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
# ...

# %%
train.obs
# Out:
#                                                       organ_tissue method  \
# cell_id
# ATCCCTGTCTGACAGT_TSP2_Muscle_rectusabdominus_10...          Muscle    10X
# ACAGCCGTCCGGACTG_TSP14_SalivaryGland_Parotid_10...  Salivary_Gland    10X
# GTCATGATCCTCTGCA_TSP1_bladder_3                            Bladder    10X
# TACCTCGTCCGGTAAT_TSP2_Vasculature_Aorta_10X_1_1        Vasculature    10X
# AACAAGACACCTGCTT_TSP7_Tongue_Anterior_10X_1_2               Tongue    10X
# ...                                                            ...    ...
# ATACCGAGTCGTATGT_TSP2_Kidney_NA_10X_1_1                     Kidney    10X
# ATACCTTCATCCGATA_TSP14_Skin_Abdomen_10X_1_1                   Skin    10X
# TTCCTCTAGGAGGTTC_TSP8_Blood_NA_10X_1_1                       Blood    10X
# TGAATGCGTCCTTTGC_TSP14_Spleen_NA_10X_2_1                    Spleen    10X
# AGAACCTGTCATGCAT_TSP14_Skin_Chest_10X_1_1                     Skin    10X
#
#                                                     donor  \
# cell_id
# ...

# %%
train.obs.method.unique()
# Out:
# ['10X', 'smartseq2']
# Categories (2, object): ['10X', 'smartseq2']
